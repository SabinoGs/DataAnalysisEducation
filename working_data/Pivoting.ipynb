# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('dados/unpivot.csv')

df
# Out:
#   Date of sale Sales person Item sold Color of item  Units sold  \
# 0     10/02/13       Prince    Laptop           Red           4
# 1     10/05/13        Jones     Mouse         Black           4
# 2     10/03/13       George     Mouse           Red           6
# 3     10/01/13        Jones  Notebook         Black           8
# 4     10/04/13        Larry  Notebook         White          10
#
#    Per unit price  Total price
# 0           35000       140000
# 1             700         3200
# 2             850         5100
# 3           25000       200000
# 4           27000       270000

# %%
"""
Pivotar uma tabela usando pd.pivot

indico index,colunas e values. 

No caso abaixo, quero que os indices sejam os dias das vendas,
as colunas os produtos e 
os valores, o preço total das vendas
"""

df.pivot('Date of sale','Item sold','Total price')
# Out:
# Item sold       Laptop   Mouse  Notebook
# Date of sale
# 10/01/13           NaN     NaN  200000.0
# 10/02/13      140000.0     NaN       NaN
# 10/03/13           NaN  5100.0       NaN
# 10/04/13           NaN     NaN  270000.0
# 10/05/13           NaN  3200.0       NaN

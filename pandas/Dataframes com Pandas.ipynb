# %%
import numpy as np
import pandas as pd

# %%
campeonatobr_df = pd.read_csv('tecnicos_brasileiros.csv')

# %%
campeonatobr_df
# Out:
#                         Treinador                Clube  \
# 0                      Abel Braga           Fluminense
# 1     Alberto Valentim (interino)            Palmeiras
# 2              Claudinei Oliveira                 Avaí
# 3                  Dorival Júnior            São Paulo
# 4                Eduardo Baptista          Ponte Preta
# 5                  Fabiano Soares  Atlético Paranaense
# 6                   Fábio Carille          Corinthians
# 7                   Gilson Kleina          Chapecoense
# 8                    Jair Ventura             Botafogo
# 9   João Paulo Sanches (interino)  Atlético Goianiense
# 10                    Levir Culpi               Santos
# 11                   Mano Menezes             Cruzeiro
# 12               Marcelo Oliveira             Coritiba
# 13            Oswaldo de Oliveira     Atlético Mineiro
# 14               Preto Casagrande                Bahia
# 15                 Reinaldo Rueda             Flamengo
# ...

# %%
campeonatobr_df.columns
# Out:
# Index(['Treinador', 'Clube', 'Contratado/efetivado em', 'Tempo no cargo'], dtype='object')

# %%
campeonatobr_df['Tempo no cargo']
# Out:
# 0             346 dias
# 1              30 dias
# 2      1 ano e 80 dias
# 3             130 dias
# 4              53 dias
# 5             124 dias
# 6             325 dias
# 7              27 dias
# 8      1 ano e 91 dias
# 9             114 dias
# 10            159 dias
# 11    1 ano e 109 dias
# 12            115 dias
# 13             47 dias
# 14             74 dias
# 15             91 dias
# 16     1 ano e 55 dias
# 17            114 dias
# 18            110 dias
# 19            166 dias
# 20             81 dias
# Name: Tempo no cargo, dtype: object

# %%
pd.DataFrame(campeonatobr_df,columns=["Treinador",'Clube'])
# Out:
#                         Treinador                Clube
# 0                      Abel Braga           Fluminense
# 1     Alberto Valentim (interino)            Palmeiras
# 2              Claudinei Oliveira                 Avaí
# 3                  Dorival Júnior            São Paulo
# 4                Eduardo Baptista          Ponte Preta
# 5                  Fabiano Soares  Atlético Paranaense
# 6                   Fábio Carille          Corinthians
# 7                   Gilson Kleina          Chapecoense
# 8                    Jair Ventura             Botafogo
# 9   João Paulo Sanches (interino)  Atlético Goianiense
# 10                    Levir Culpi               Santos
# 11                   Mano Menezes             Cruzeiro
# 12               Marcelo Oliveira             Coritiba
# 13            Oswaldo de Oliveira     Atlético Mineiro
# 14               Preto Casagrande                Bahia
# 15                 Reinaldo Rueda             Flamengo
# ...

# %%
pd.DataFrame(campeonatobr_df,columns=["Treinador",'Clube','Pais'])
# Out:
#                         Treinador                Clube  Pais
# 0                      Abel Braga           Fluminense   NaN
# 1     Alberto Valentim (interino)            Palmeiras   NaN
# 2              Claudinei Oliveira                 Avaí   NaN
# 3                  Dorival Júnior            São Paulo   NaN
# 4                Eduardo Baptista          Ponte Preta   NaN
# 5                  Fabiano Soares  Atlético Paranaense   NaN
# 6                   Fábio Carille          Corinthians   NaN
# 7                   Gilson Kleina          Chapecoense   NaN
# 8                    Jair Ventura             Botafogo   NaN
# 9   João Paulo Sanches (interino)  Atlético Goianiense   NaN
# 10                    Levir Culpi               Santos   NaN
# 11                   Mano Menezes             Cruzeiro   NaN
# 12               Marcelo Oliveira             Coritiba   NaN
# 13            Oswaldo de Oliveira     Atlético Mineiro   NaN
# ...

# %%
campeonatobr_df.head()
# Out:
#                      Treinador        Clube      Contratado/efetivado em  \
# 0                   Abel Braga   Fluminense        1 de dezembro de 2016
# 1  Alberto Valentim (interino)    Palmeiras   13 de outubro de 2017[200]
# 2           Claudinei Oliveira         Avaí    24 de agosto de 2016[183]
# 3               Dorival Júnior    São Paulo      5 de julho de 2017[189]
# 4             Eduardo Baptista  Ponte Preta  20 de setembro de 2017[198]
#
#     Tempo no cargo
# 0         346 dias
# 1          30 dias
# 2  1 ano e 80 dias
# 3         130 dias
# 4          53 dias

# %%
campeonatobr_df.loc[2]
# Out:
# Treinador                         Claudinei Oliveira
# Clube                                           Avaí
# Contratado/efetivado em    24 de agosto de 2016[183]
# Tempo no cargo                       1 ano e 80 dias
# estadio                                       Brasil
# Pais                                          Brasil
# Name: 2, dtype: object

# %%
campeonatobr_df['Pais'] = 'Brasil'
campeonatobr_df
# Out:
#                         Treinador                Clube  \
# 0                      Abel Braga           Fluminense
# 1     Alberto Valentim (interino)            Palmeiras
# 2              Claudinei Oliveira                 Avaí
# 3                  Dorival Júnior            São Paulo
# 4                Eduardo Baptista          Ponte Preta
# 5                  Fabiano Soares  Atlético Paranaense
# 6                   Fábio Carille          Corinthians
# 7                   Gilson Kleina          Chapecoense
# 8                    Jair Ventura             Botafogo
# 9   João Paulo Sanches (interino)  Atlético Goianiense
# 10                    Levir Culpi               Santos
# 11                   Mano Menezes             Cruzeiro
# 12               Marcelo Oliveira             Coritiba
# 13            Oswaldo de Oliveira     Atlético Mineiro
# 14               Preto Casagrande                Bahia
# 15                 Reinaldo Rueda             Flamengo
# ...

# %%
campeonatobr_df['Pais'] = np.arange(21)
campeonatobr_df
# Out:
#                         Treinador                Clube  \
# 0                      Abel Braga           Fluminense
# 1     Alberto Valentim (interino)            Palmeiras
# 2              Claudinei Oliveira                 Avaí
# 3                  Dorival Júnior            São Paulo
# 4                Eduardo Baptista          Ponte Preta
# 5                  Fabiano Soares  Atlético Paranaense
# 6                   Fábio Carille          Corinthians
# 7                   Gilson Kleina          Chapecoense
# 8                    Jair Ventura             Botafogo
# 9   João Paulo Sanches (interino)  Atlético Goianiense
# 10                    Levir Culpi               Santos
# 11                   Mano Menezes             Cruzeiro
# 12               Marcelo Oliveira             Coritiba
# 13            Oswaldo de Oliveira     Atlético Mineiro
# 14               Preto Casagrande                Bahia
# 15                 Reinaldo Rueda             Flamengo
# ...

# %%
"""atribuir uma Serie a uma columa do DataFRame"""

estadios = pd.Series(np.arange(1000,1021))

campeonatobr_df['estadio'] = estadios

campeonatobr_df
# Out:
#                         Treinador                Clube  \
# 0                      Abel Braga           Fluminense
# 1     Alberto Valentim (interino)            Palmeiras
# 2              Claudinei Oliveira                 Avaí
# 3                  Dorival Júnior            São Paulo
# 4                Eduardo Baptista          Ponte Preta
# 5                  Fabiano Soares  Atlético Paranaense
# 6                   Fábio Carille          Corinthians
# 7                   Gilson Kleina          Chapecoense
# 8                    Jair Ventura             Botafogo
# 9   João Paulo Sanches (interino)  Atlético Goianiense
# 10                    Levir Culpi               Santos
# 11                   Mano Menezes             Cruzeiro
# 12               Marcelo Oliveira             Coritiba
# 13            Oswaldo de Oliveira     Atlético Mineiro
# 14               Preto Casagrande                Bahia
# 15                 Reinaldo Rueda             Flamengo
# ...

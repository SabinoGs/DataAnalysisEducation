# %%
import numpy as np
import pandas as pd

# %%
"""
Podemos indentificar se há ou nao headers no CSV  
com o argumento 'header'
"""
df = pd.read_csv('mushrooms.csv')
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
"""
O csv abaixo precisou de um encoding diferente do utf-8 para ser buildado como 
DataFrame. Para descobrir o encoding, abra um editor de texto e veja.
"""

df2 = pd.read_table('TA_PRECOS_MEDICAMENTOS.csv',delimiter="|",encoding='Windows 1252')
df2.head()
# Out:
#           NU_CNPJ                                NO_RAZAO_SOCIAL  \
# 0  60726692000181               MARJAN INDÚSTRIA E COMÉRCIO LTDA
# 1  60726692000181               MARJAN INDÚSTRIA E COMÉRCIO LTDA
# 2   4038750000103  LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 3  60726692000181               MARJAN INDÚSTRIA E COMÉRCIO LTDA
# 4   4038750000103  LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
#
#      NU_REGISTRO      CO_GGREM         CO_EAN    NO_PRODUTO  \
# 0  1015501950021  5.248018e+14  7896226102634       OSTENAN
# 1  1015501950072  5.248018e+14  7896226102627       OSTENAN
# 2  1206900220020  5.238038e+14  7730711011233  TEICOPLANINA
# 3  1015500410028  5.248001e+14  7896226100449      AMBROTEN
# 4  1206900260022  5.238033e+14  7730711011493  OXALIPLATINA
#
#                                      DS_APRESENTACAO       DS_CAS  \
# 0                           10 MG COMP REV CX COM 30  121268-17-5
# 1                           10 MG COMP REV CX COM 15  121268-17-5
# ...
